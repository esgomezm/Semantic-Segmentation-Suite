# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# os.chdir("/content/gdrive/My Drive/TFG/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite")
os.chdir('/content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite/')
# !ls
# Out:
# builders     get_data_ready.py	requirements.txt    test.py
# checkpoints  iou_vs_epochs.png	results		    train4drive.py
# docs	     models		SemSeg4Colab.ipynb  train.py
# frontends    predict.py		server_training.py  utils

# %%
# !pip install scipy==1.1.0
# !pip install tensorflow==1.15

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %% [markdown]
# # Training

# %%
# !python train4drive.py --dataset "/content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/clean_data/data4training/SEG" --num_epochs 500 --batch_size 1 --learning_rate 0.01 --continue_training True --checkpoint "Thu May 14 17:20:51 2020"
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite/frontends/mobilenet_base.py:401: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite/frontends/inception_utils.py:37: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# ...

# %% [markdown]
# ## Keep training the last model
# Just write the name of the folder you want to target. Then, if necessary, increase the number of epochs so it keeps training.
# In this case, as it only trained 100 epochs, we are going to keep 500.

# %%
# !python train4drive.py --dataset "/content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/clean_data/data4training/SEG" --num_epochs 500 --batch_size 1 --learning_rate 0.01 --continue_training True --checkpoint "Thu May 14 17:20:51 2020"
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite/frontends/mobilenet_base.py:401: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Estibaliz Gomez de Mariscal/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite/frontends/inception_utils.py:37: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# ...

# %% [markdown]
# # Inference
# Esti: I didn't touch this part. I gues it works, but you need to test it.

# %%
# !python test.py

# %%
from scipy.spatial.distance import directed_hausdorff
import numpy as np
import os
# !pip install SimpleITK
import SimpleITK as sitk

path2data = '/content/gdrive/My Drive/TFG/TFG MARINA CALZADA/Seg_github/Semantic-Segmentation-Suite/Test_Binary/'

def load_itk_image(filename):
    itkimage = sitk.ReadImage(filename)
    numpyImage = sitk.GetArrayFromImage(itkimage)
    return numpyImage

HM=np.zeros(172)
i=0
for file in os.listdir(path2data):
  if file.endswith('_gt.png'):
    filename=file.replace('gt.png','')
    frame = load_itk_image(path2data + filename + 'pred.png')[:,:,1]
    gt = load_itk_image(path2data + filename + 'gt.png') [:,:,1]
    HM [i] = directed_hausdorff(frame, gt)[0]
    # if HM[i]==0:
    #   sub=gt-frame
    #   tot=sub.sum()
    #   print(tot)
    i +=1
    
mean_HM=np.mean(HM)
print(mean_HM)
# Out:
# 2.2178445891342116

# %%
import numpy as np
choices=np.array([0,0,0.2,0])
if choices>=1:
  print('Ok')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-fced0d5ed520> in <module>()
#       1 import numpy as np
#       2 choices=np.array([0,0,0.2,0])
# ----> 3 if choices>=1:
#       4   print('Ok')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
z=np.count_nonzero(choices)
print(z)
